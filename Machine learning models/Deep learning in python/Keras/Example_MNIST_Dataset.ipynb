# %% [markdown]
# # Example: MNIST Dataset

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np

# Get data
df_train = pd.read_csv('./Dataset/mnist_train.csv')
df_test = pd.read_csv('./Dataset/mnist_test.csv')

y_train = df_train['label']
y_test = df_test['label']
X_train = df_train.iloc[:, 1:]
X_test = df_test.iloc[:, 1:]

# %% [markdown]
# ## Model

# %%
model = Sequential([
    Dense(units=64, input_shape=(784,), activation='relu'),
    Dense(units=32, activation='relu'),
    Dense(units=16, activation='relu'),
    Dense(units=10, activation='softmax')
])

model.compile(Adam(learning_rate=.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_11 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_12 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_14 (Dense)             (None, 10)                170
# ...
# Total params: 53,018
# Trainable params: 53,018
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
model.fit(x=X_train, y=y_train, validation_split=0.1, batch_size=10, epochs=40, shuffle=True, verbose=1)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/40
# 54000/54000 [==============================] - 4s 78us/sample - loss: 3.0955 - accuracy: 0.6112 - val_loss: 0.6951 - val_accuracy: 0.8190
# Epoch 2/40
# 54000/54000 [==============================] - 4s 73us/sample - loss: 0.5702 - accuracy: 0.8552 - val_loss: 0.3673 - val_accuracy: 0.9068
# Epoch 3/40
# 54000/54000 [==============================] - 4s 73us/sample - loss: 0.3492 - accuracy: 0.9086 - val_loss: 0.2683 - val_accuracy: 0.9303
# Epoch 4/40
# 54000/54000 [==============================] - 4s 73us/sample - loss: 0.2586 - accuracy: 0.9310 - val_loss: 0.2303 - val_accuracy: 0.9413
# Epoch 5/40
# 54000/54000 [==============================] - 4s 73us/sample - loss: 0.2035 - accuracy: 0.9439 - val_loss: 0.1950 - val_accuracy: 0.9483
# Epoch 6/40
# 54000/54000 [==============================] - 4s 74us/sample - loss: 0.1675 - accuracy: 0.9530 - val_loss: 0.1844 - val_accuracy: 0.9548
# Epoch 7/40
# ...

# %% [markdown]
# ## Test

# %%
_, accuracy = model.evaluate(X_test, y_test)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 10000/10000 [==============================] - 0s 20us/sample - loss: 0.2965 - accuracy: 0.9647
# Accuracy: 96.47
